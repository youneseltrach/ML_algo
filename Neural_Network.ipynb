# %% [markdown]
# <a href="https://colab.research.google.com/github/youneseltrach/ML_algo/blob/main/Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
model = tf.keras.Sequential(
    [
        tf.keras.layers.Dense (2,input_dim = 2, activation = 'relu'),
        tf.keras.layers.Dense (4, activation = 'relu'), # I add this layer with 4 units for omit the problem of xor
        tf.keras.layers.Dense (1, activation = 'sigmoid')
    ]
)

# %%
model.compile (loss = 'binary_crossentropy', optimizer = 'adam')

# %%
X_or = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y_or = np.array([[0], [1], [1], [1]])

X_and = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y_and = np.array([[0], [0], [0], [1]])

# XOR dataset
X_xor = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y_xor = np.array([[0], [1], [1], [0]])

# %%
model.fit(X_or, y_or, epochs = 10000)

# %%
model.fit(X_xor, y_xor, epochs = 10000)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Epoch 7027/10000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 7028/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0022
# Epoch 7029/10000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0022
# Epoch 7030/10000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 7031/10000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0022
# Epoch 7032/10000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0022
# Epoch 7033/10000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0022
# Epoch 7034/10000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0022
# Epoch 7035/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0022
# Epoch 7036/10000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0022
# Epoch 7037/10000
# ...

# %%
model.fit(X_and, y_and, epochs = 10000)

# %%
def predict (x):
  pre = model.predict (x)
  result = np.zeros((len(pre),1))
  for i in range (len(pre)):
    if pre[i] > 0.5:
      result[i] = 1
    else:
      result[i] = 0
  return result

# %%
predict (X_or)
# Out:
# 1/1 [==============================] - 0s 99ms/step
# array([[0.],
#        [1.],
#        [1.],
#        [0.]])
